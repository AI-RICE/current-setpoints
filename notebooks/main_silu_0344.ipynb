# %%
import os
import pickle
import sys

import numpy as np
import torch

root_dir = os.path.abspath("..")
data_dir = os.path.join(root_dir, "data")
os.makedirs(data_dir, exist_ok=True)
if root_dir not in sys.path:
    sys.path.append(root_dir)

from current_setpoints.parameters import Flux_IEEEMachine2, IEEEMachine2
from current_setpoints.simulation import Transform
from current_setpoints.optimization import (
    ModelAnalytical,
    ModelNeural,
    MotorOptimizer,
    calculate_grid,
    get_correction_grid,
    grid_to_data,
)
from current_setpoints.utils.neural import load_neural_model
from current_setpoints.utils.plotting import plot_grid_segments

# %%
flux = Flux_IEEEMachine2()
machine = IEEEMachine2()

NMAX = 1800  # mechanical RPM
machine.set_max_pars(curr_max=30.0, volt_max=13.0, omega_max=NMAX)
transform = Transform(machine=machine, flux=flux, add_volt_0=False)

analytical_model = ModelAnalytical(machine=machine, flux=flux)
solver_opts = {"disp": False, "ftol": 1e-8, "maxiter": 500, "eps": 1e-8}
optimizer = MotorOptimizer(model=analytical_model, opts=solver_opts)

grid_opts = {"n_torq": 201, "n_omega": 201, "torq_min": 0.0, "omega_min": 0.0}

# %%
# 1. Baseline grid: analytical optimum at every (T, omega) operating point.
filename = os.path.join(data_dir, "IEEETIE_machine2_baseline.pkl")

if os.path.isfile(filename):
    print(f"Loading existing baseline grid from '{filename}'...")
    with open(filename, "rb") as file:
        grid_result = pickle.load(file)
else:
    print("Starting baseline grid calculation. This may take a few minutes...")
    grid_result = calculate_grid(
        optimizer=optimizer, transform=transform, opts=grid_opts, mode="standard"
    )
    with open(filename, "wb") as file:
        pickle.dump(grid_result, file)
    print(f"Baseline grid successfully calculated and saved to '{filename}'")

print("Plotting baseline grid...")
machine_data = grid_to_data(grid_result, k_skip=1)
plot_grid_segments(machine_data, title="1. Baseline Grid")
# Out:
# Starting baseline grid calculation. This may take a few minutes...
# Starting Standard Grid Calculation...
# Calculating: Omega step 1/201 (0.0 RPM)
# Calculating: Omega step 2/201 (9.0 RPM)
# Calculating: Omega step 3/201 (18.0 RPM)
# Calculating: Omega step 4/201 (27.0 RPM)
# Calculating: Omega step 5/201 (36.0 RPM)
# Calculating: Omega step 6/201 (45.0 RPM)
# Calculating: Omega step 7/201 (54.0 RPM)
# Calculating: Omega step 8/201 (63.0 RPM)
# Calculating: Omega step 9/201 (72.0 RPM)
# Calculating: Omega step 10/201 (81.0 RPM)
# Calculating: Omega step 11/201 (90.0 RPM)
# Calculating: Omega step 12/201 (99.0 RPM)
# Calculating: Omega step 13/201 (108.0 RPM)
# Calculating: Omega step 14/201 (117.0 RPM)
# Calculating: Omega step 15/201 (126.0 RPM)
# Calculating: Omega step 16/201 (135.0 RPM)
# Calculating: Omega step 17/201 (144.0 RPM)
# Calculating: Omega step 18/201 (153.0 RPM)
# Calculating: Omega step 19/201 (162.0 RPM)
# Calculating: Omega step 20/201 (171.0 RPM)
# Calculating: Omega step 21/201 (180.0 RPM)
# Calculating: Omega step 22/201 (189.0 RPM)
# Calculating: Omega step 23/201 (198.0 RPM)
# Calculating: Omega step 24/201 (207.0 RPM)
# Calculating: Omega step 25/201 (216.0 RPM)
# Calculating: Omega step 26/201 (225.0 RPM)
# Calculating: Omega step 27/201 (234.0 RPM)
# Calculating: Omega step 28/201 (243.0 RPM)
# Calculating: Omega step 29/201 (252.0 RPM)
# Calculating: Omega step 30/201 (261.0 RPM)
# Calculating: Omega step 31/201 (270.0 RPM)
# Calculating: Omega step 32/201 (279.0 RPM)
# Calculating: Omega step 33/201 (288.0 RPM)
# Calculating: Omega step 34/201 (297.0 RPM)
# Calculating: Omega step 35/201 (306.0 RPM)
# Calculating: Omega step 36/201 (315.0 RPM)
# Calculating: Omega step 37/201 (324.0 RPM)
# Calculating: Omega step 38/201 (333.0 RPM)
# Calculating: Omega step 39/201 (342.0 RPM)
# Calculating: Omega step 40/201 (351.0 RPM)
# Calculating: Omega step 41/201 (360.0 RPM)
# Calculating: Omega step 42/201 (369.0 RPM)
# Calculating: Omega step 43/201 (378.0 RPM)
# Calculating: Omega step 44/201 (387.0 RPM)
# Calculating: Omega step 45/201 (396.0 RPM)
# Calculating: Omega step 46/201 (405.0 RPM)
# Calculating: Omega step 47/201 (414.0 RPM)
# Calculating: Omega step 48/201 (423.0 RPM)
# Calculating: Omega step 49/201 (432.0 RPM)
# Calculating: Omega step 50/201 (441.0 RPM)
# Calculating: Omega step 51/201 (450.0 RPM)
# Calculating: Omega step 52/201 (459.0 RPM)
# Calculating: Omega step 53/201 (468.0 RPM)
# Calculating: Omega step 54/201 (477.0 RPM)
# Calculating: Omega step 55/201 (486.0 RPM)
# Calculating: Omega step 56/201 (495.0 RPM)
# Calculating: Omega step 57/201 (504.0 RPM)
# Calculating: Omega step 58/201 (513.0 RPM)
# Calculating: Omega step 59/201 (522.0 RPM)
# Calculating: Omega step 60/201 (531.0 RPM)
# Calculating: Omega step 61/201 (540.0 RPM)
# Calculating: Omega step 62/201 (549.0 RPM)
# Calculating: Omega step 63/201 (558.0 RPM)
# Calculating: Omega step 64/201 (567.0 RPM)
# Calculating: Omega step 65/201 (576.0 RPM)
# Calculating: Omega step 66/201 (585.0 RPM)
# Calculating: Omega step 67/201 (594.0 RPM)
# Calculating: Omega step 68/201 (603.0 RPM)
# Calculating: Omega step 69/201 (612.0 RPM)
# Calculating: Omega step 70/201 (621.0 RPM)
# Calculating: Omega step 71/201 (630.0 RPM)
# Calculating: Omega step 72/201 (639.0 RPM)
# Calculating: Omega step 73/201 (648.0 RPM)
# Calculating: Omega step 74/201 (657.0 RPM)
# Calculating: Omega step 75/201 (666.0 RPM)
# Calculating: Omega step 76/201 (675.0 RPM)
# Calculating: Omega step 77/201 (684.0 RPM)
# Calculating: Omega step 78/201 (693.0 RPM)
# Calculating: Omega step 79/201 (702.0 RPM)
# Calculating: Omega step 80/201 (711.0 RPM)
# Calculating: Omega step 81/201 (720.0 RPM)
# Calculating: Omega step 82/201 (729.0 RPM)
# Calculating: Omega step 83/201 (738.0 RPM)
# Calculating: Omega step 84/201 (747.0 RPM)
# Calculating: Omega step 85/201 (756.0 RPM)
# Calculating: Omega step 86/201 (765.0 RPM)
# Calculating: Omega step 87/201 (774.0 RPM)
# Calculating: Omega step 88/201 (783.0 RPM)
# Calculating: Omega step 89/201 (792.0 RPM)
# Calculating: Omega step 90/201 (801.0 RPM)
# Calculating: Omega step 91/201 (810.0 RPM)
# Calculating: Omega step 92/201 (819.0 RPM)
# Calculating: Omega step 93/201 (828.0 RPM)
# Calculating: Omega step 94/201 (837.0 RPM)
# Calculating: Omega step 95/201 (846.0 RPM)
# Calculating: Omega step 96/201 (855.0 RPM)
# Calculating: Omega step 97/201 (864.0 RPM)
# Calculating: Omega step 98/201 (873.0 RPM)
# Calculating: Omega step 99/201 (882.0 RPM)
# Calculating: Omega step 100/201 (891.0 RPM)
# Calculating: Omega step 101/201 (900.0 RPM)
# Calculating: Omega step 102/201 (909.0 RPM)
# Calculating: Omega step 103/201 (918.0 RPM)
# Calculating: Omega step 104/201 (927.0 RPM)
# Calculating: Omega step 105/201 (936.0 RPM)
# Calculating: Omega step 106/201 (945.0 RPM)
# Calculating: Omega step 107/201 (954.0 RPM)
# Calculating: Omega step 108/201 (963.0 RPM)
# Calculating: Omega step 109/201 (972.0 RPM)
# Calculating: Omega step 110/201 (981.0 RPM)
# Calculating: Omega step 111/201 (990.0 RPM)
# Calculating: Omega step 112/201 (999.0 RPM)
# Calculating: Omega step 113/201 (1008.0 RPM)
# Calculating: Omega step 114/201 (1017.0 RPM)
# Calculating: Omega step 115/201 (1026.0 RPM)
# Calculating: Omega step 116/201 (1035.0 RPM)
# Calculating: Omega step 117/201 (1044.0 RPM)
# Calculating: Omega step 118/201 (1053.0 RPM)
# Calculating: Omega step 119/201 (1062.0 RPM)
# Calculating: Omega step 120/201 (1071.0 RPM)
# Calculating: Omega step 121/201 (1080.0 RPM)
# Calculating: Omega step 122/201 (1089.0 RPM)
# Calculating: Omega step 123/201 (1098.0 RPM)
# Calculating: Omega step 124/201 (1107.0 RPM)
# Calculating: Omega step 125/201 (1116.0 RPM)
# Calculating: Omega step 126/201 (1125.0 RPM)
# Calculating: Omega step 127/201 (1134.0 RPM)
# Calculating: Omega step 128/201 (1143.0 RPM)
# Calculating: Omega step 129/201 (1152.0 RPM)
# Calculating: Omega step 130/201 (1161.0 RPM)
# Calculating: Omega step 131/201 (1170.0 RPM)
# Calculating: Omega step 132/201 (1179.0 RPM)
# Calculating: Omega step 133/201 (1188.0 RPM)
# Calculating: Omega step 134/201 (1197.0 RPM)
# Calculating: Omega step 135/201 (1206.0 RPM)
# Calculating: Omega step 136/201 (1215.0 RPM)
# Calculating: Omega step 137/201 (1224.0 RPM)
# Calculating: Omega step 138/201 (1233.0 RPM)
# Calculating: Omega step 139/201 (1242.0 RPM)
# Calculating: Omega step 140/201 (1251.0 RPM)
# Calculating: Omega step 141/201 (1260.0 RPM)
# Calculating: Omega step 142/201 (1269.0 RPM)
# Calculating: Omega step 143/201 (1278.0 RPM)
# Calculating: Omega step 144/201 (1287.0 RPM)
# Calculating: Omega step 145/201 (1296.0 RPM)
# Calculating: Omega step 146/201 (1305.0 RPM)
# Calculating: Omega step 147/201 (1314.0 RPM)
# Calculating: Omega step 148/201 (1323.0 RPM)
# Calculating: Omega step 149/201 (1332.0 RPM)
# Calculating: Omega step 150/201 (1341.0 RPM)
# Calculating: Omega step 151/201 (1350.0 RPM)
# Calculating: Omega step 152/201 (1359.0 RPM)
# Calculating: Omega step 153/201 (1368.0 RPM)
# Calculating: Omega step 154/201 (1377.0 RPM)
# Calculating: Omega step 155/201 (1386.0 RPM)
# Calculating: Omega step 156/201 (1395.0 RPM)
# Calculating: Omega step 157/201 (1404.0 RPM)
# Calculating: Omega step 158/201 (1413.0 RPM)
# Calculating: Omega step 159/201 (1422.0 RPM)
# Calculating: Omega step 160/201 (1431.0 RPM)
# Calculating: Omega step 161/201 (1440.0 RPM)
# Calculating: Omega step 162/201 (1449.0 RPM)
# Calculating: Omega step 163/201 (1458.0 RPM)
# Calculating: Omega step 164/201 (1467.0 RPM)
# Calculating: Omega step 165/201 (1476.0 RPM)
# Calculating: Omega step 166/201 (1485.0 RPM)
# Calculating: Omega step 167/201 (1494.0 RPM)
# Calculating: Omega step 168/201 (1503.0 RPM)
# Calculating: Omega step 169/201 (1512.0 RPM)
# Calculating: Omega step 170/201 (1521.0 RPM)
# Calculating: Omega step 171/201 (1530.0 RPM)
# Calculating: Omega step 172/201 (1539.0 RPM)
# Calculating: Omega step 173/201 (1548.0 RPM)
# Calculating: Omega step 174/201 (1557.0 RPM)
# Calculating: Omega step 175/201 (1566.0 RPM)
# Calculating: Omega step 176/201 (1575.0 RPM)
# Calculating: Omega step 177/201 (1584.0 RPM)
# Calculating: Omega step 178/201 (1593.0 RPM)
# Calculating: Omega step 179/201 (1602.0 RPM)
# Calculating: Omega step 180/201 (1611.0 RPM)
# Calculating: Omega step 181/201 (1620.0 RPM)
# Calculating: Omega step 182/201 (1629.0 RPM)
# Calculating: Omega step 183/201 (1638.0 RPM)
# Calculating: Omega step 184/201 (1647.0 RPM)
# Calculating: Omega step 185/201 (1656.0 RPM)
# Calculating: Omega step 186/201 (1665.0 RPM)
# Calculating: Omega step 187/201 (1674.0 RPM)
# Calculating: Omega step 188/201 (1683.0 RPM)
# Calculating: Omega step 189/201 (1692.0 RPM)
# Calculating: Omega step 190/201 (1701.0 RPM)
# Calculating: Omega step 191/201 (1710.0 RPM)
# Calculating: Omega step 192/201 (1719.0 RPM)
# Calculating: Omega step 193/201 (1728.0 RPM)
# Calculating: Omega step 194/201 (1737.0 RPM)
# Calculating: Omega step 195/201 (1746.0 RPM)
# Calculating: Omega step 196/201 (1755.0 RPM)
# Calculating: Omega step 197/201 (1764.0 RPM)
# Calculating: Omega step 198/201 (1773.0 RPM)
# Calculating: Omega step 199/201 (1782.0 RPM)
# Calculating: Omega step 200/201 (1791.0 RPM)
# Calculating: Omega step 201/201 (1800.0 RPM)
# Standard Grid Calculation Complete.
# Baseline grid successfully calculated and saved to 'c:\Users\matas\Desktop\CurrentSetpoints_main\data\IEEETIE_machine2_baseline.pkl'
# Plotting baseline grid...

# %%
# 2. Correction grid: re-evaluate baseline currents through the trained NTM
#    to obtain the neural-predicted torque at every operating point.
DEVICE = torch.device("cpu")

weights_dir = os.path.join(root_dir, "weights")
MODEL_SAVE_PATH = os.path.join(weights_dir, "NTM_Weights_0344.pth")
SCALER_SAVE_PATH = os.path.join(weights_dir, "NTM_Scaler_0344.npy")
INPUT_SIZE = 5
OPTIMAL_HIDDEN_SIZE = 12

print("Loading trained NeuralTorquePredictor...")
neural_net, scaler = load_neural_model(
    weights_path=MODEL_SAVE_PATH,
    scaler_path=SCALER_SAVE_PATH,
    hidden_size=OPTIMAL_HIDDEN_SIZE,
    input_size=INPUT_SIZE,
    device=DEVICE,
)

neural_model_wrapper = ModelNeural(
    machine=machine,
    flux=flux,
    neural_model=neural_net,
    scaler=scaler,
    device=DEVICE,
)

solver_opts_neural = {"disp": False, "ftol": 1e-5, "maxiter": 2500, "eps": 1e-4}
neural_optimizer = MotorOptimizer(model=neural_model_wrapper, opts=solver_opts_neural)

corr_filename = os.path.join(data_dir, "IEEETIE_machine2_correction_0344.pkl")
if os.path.isfile(corr_filename):
    print(f"Loading existing correction grid from '{corr_filename}'...")
    with open(corr_filename, "rb") as file:
        correction_grid_result = pickle.load(file)
else:
    print("Starting correction grid calculation...")
    correction_grid_result = get_correction_grid(
        dict_grid=grid_result,
        model=neural_model_wrapper,
    )
    with open(corr_filename, "wb") as file:
        pickle.dump(correction_grid_result, file)
    print(f"Correction grid successfully calculated and saved to '{corr_filename}'")

print("Plotting correction grid (neural-predicted torques)...")
correction_machine_data = grid_to_data(correction_grid_result, k_skip=1)
plot_grid_segments(
    correction_machine_data,
    title="2. Correction Grid",
    override_torq_2d=correction_grid_result["grid_torq_neural"],
)
# Out:
# Loading trained NeuralTorquePredictor...
# Starting correction grid calculation...
# Computing ML Correction Grid...
# Correction grid successfully calculated and saved to 'c:\Users\matas\Desktop\CurrentSetpoints_main\data\IEEETIE_machine2_correction_0344.pkl'
# Plotting correction grid (neural-predicted torques)...

# %%
# 3. Recalculated grid: re-run the optimizer with the neural torque model,
#    using baseline currents as warm starts and neural torque as the target.
recalc_filename = os.path.join(data_dir, "IEEETIE_machine2_recalculated_0344.pkl")

if os.path.isfile(recalc_filename):
    print(f"Loading existing recalculated grid from '{recalc_filename}'...")
    with open(recalc_filename, "rb") as file:
        recalc_grid_result = pickle.load(file)
else:
    print(
        "Starting recalculated grid calculation. Using baseline currents as warm starts..."
    )
    recalc_grid_result = calculate_grid(
        optimizer=neural_optimizer,
        transform=transform,
        opts=grid_opts,
        mode="recalculated",
        dict_grid_corr=correction_grid_result,
    )
    with open(recalc_filename, "wb") as file:
        pickle.dump(recalc_grid_result, file)
    print(f"Recalculated grid successfully calculated and saved to '{recalc_filename}'")

print("Plotting recalculated grid...")
recalc_machine_data = grid_to_data(recalc_grid_result, k_skip=1)
plot_grid_segments(
    recalc_machine_data,
    title="3. Recalculated Grid",
    override_torq_2d=recalc_grid_result["grid_torq_neural"],
)
# Out:
# Starting recalculated grid calculation. Using baseline currents as warm starts...
# Starting Recalculated Grid Calculation...
# Calculating: Omega step 1/201 (0.0 RPM)
# Calculating: Omega step 2/201 (9.0 RPM)
# Calculating: Omega step 3/201 (18.0 RPM)
# Calculating: Omega step 4/201 (27.0 RPM)
# Calculating: Omega step 5/201 (36.0 RPM)
# Calculating: Omega step 6/201 (45.0 RPM)
# Calculating: Omega step 7/201 (54.0 RPM)
# Calculating: Omega step 8/201 (63.0 RPM)
# Calculating: Omega step 9/201 (72.0 RPM)
# Calculating: Omega step 10/201 (81.0 RPM)
# Calculating: Omega step 11/201 (90.0 RPM)
# Calculating: Omega step 12/201 (99.0 RPM)
# Calculating: Omega step 13/201 (108.0 RPM)
# Calculating: Omega step 14/201 (117.0 RPM)
# Calculating: Omega step 15/201 (126.0 RPM)
# Calculating: Omega step 16/201 (135.0 RPM)
# Calculating: Omega step 17/201 (144.0 RPM)
# Calculating: Omega step 18/201 (153.0 RPM)
# Calculating: Omega step 19/201 (162.0 RPM)
# Calculating: Omega step 20/201 (171.0 RPM)
# Calculating: Omega step 21/201 (180.0 RPM)
# Calculating: Omega step 22/201 (189.0 RPM)
# Calculating: Omega step 23/201 (198.0 RPM)
# Calculating: Omega step 24/201 (207.0 RPM)
# Calculating: Omega step 25/201 (216.0 RPM)
# Calculating: Omega step 26/201 (225.0 RPM)
# Calculating: Omega step 27/201 (234.0 RPM)
# Calculating: Omega step 28/201 (243.0 RPM)
# Calculating: Omega step 29/201 (252.0 RPM)
# Calculating: Omega step 30/201 (261.0 RPM)
# Calculating: Omega step 31/201 (270.0 RPM)
# Calculating: Omega step 32/201 (279.0 RPM)
# Calculating: Omega step 33/201 (288.0 RPM)
# Calculating: Omega step 34/201 (297.0 RPM)
# Calculating: Omega step 35/201 (306.0 RPM)
# Calculating: Omega step 36/201 (315.0 RPM)
# Calculating: Omega step 37/201 (324.0 RPM)
# Calculating: Omega step 38/201 (333.0 RPM)
# Calculating: Omega step 39/201 (342.0 RPM)
# Calculating: Omega step 40/201 (351.0 RPM)
# Calculating: Omega step 41/201 (360.0 RPM)
# Calculating: Omega step 42/201 (369.0 RPM)
# Calculating: Omega step 43/201 (378.0 RPM)
# Calculating: Omega step 44/201 (387.0 RPM)
# Calculating: Omega step 45/201 (396.0 RPM)
# Calculating: Omega step 46/201 (405.0 RPM)
# Calculating: Omega step 47/201 (414.0 RPM)
# Calculating: Omega step 48/201 (423.0 RPM)
# Calculating: Omega step 49/201 (432.0 RPM)
# Calculating: Omega step 50/201 (441.0 RPM)
# Calculating: Omega step 51/201 (450.0 RPM)
# Calculating: Omega step 52/201 (459.0 RPM)
# Calculating: Omega step 53/201 (468.0 RPM)
# Calculating: Omega step 54/201 (477.0 RPM)
# Calculating: Omega step 55/201 (486.0 RPM)
# Calculating: Omega step 56/201 (495.0 RPM)
# Calculating: Omega step 57/201 (504.0 RPM)
# Calculating: Omega step 58/201 (513.0 RPM)
# Calculating: Omega step 59/201 (522.0 RPM)
# Calculating: Omega step 60/201 (531.0 RPM)
# Calculating: Omega step 61/201 (540.0 RPM)
# Calculating: Omega step 62/201 (549.0 RPM)
# Calculating: Omega step 63/201 (558.0 RPM)
# Calculating: Omega step 64/201 (567.0 RPM)
# Calculating: Omega step 65/201 (576.0 RPM)
# Calculating: Omega step 66/201 (585.0 RPM)
# Calculating: Omega step 67/201 (594.0 RPM)
# Calculating: Omega step 68/201 (603.0 RPM)
# Calculating: Omega step 69/201 (612.0 RPM)
# Calculating: Omega step 70/201 (621.0 RPM)
# Calculating: Omega step 71/201 (630.0 RPM)
# Calculating: Omega step 72/201 (639.0 RPM)
# Calculating: Omega step 73/201 (648.0 RPM)
# Calculating: Omega step 74/201 (657.0 RPM)
# Calculating: Omega step 75/201 (666.0 RPM)
# Calculating: Omega step 76/201 (675.0 RPM)
# Calculating: Omega step 77/201 (684.0 RPM)
# Calculating: Omega step 78/201 (693.0 RPM)
# Calculating: Omega step 79/201 (702.0 RPM)
# Calculating: Omega step 80/201 (711.0 RPM)
# Calculating: Omega step 81/201 (720.0 RPM)
# Calculating: Omega step 82/201 (729.0 RPM)
# Calculating: Omega step 83/201 (738.0 RPM)
# Calculating: Omega step 84/201 (747.0 RPM)
# Calculating: Omega step 85/201 (756.0 RPM)
# Calculating: Omega step 86/201 (765.0 RPM)
# Calculating: Omega step 87/201 (774.0 RPM)
# Calculating: Omega step 88/201 (783.0 RPM)
# Calculating: Omega step 89/201 (792.0 RPM)
# Calculating: Omega step 90/201 (801.0 RPM)
# Calculating: Omega step 91/201 (810.0 RPM)
# Calculating: Omega step 92/201 (819.0 RPM)
# Calculating: Omega step 93/201 (828.0 RPM)
# Calculating: Omega step 94/201 (837.0 RPM)
# Calculating: Omega step 95/201 (846.0 RPM)
# Calculating: Omega step 96/201 (855.0 RPM)
# Calculating: Omega step 97/201 (864.0 RPM)
# Calculating: Omega step 98/201 (873.0 RPM)
# Calculating: Omega step 99/201 (882.0 RPM)
# Calculating: Omega step 100/201 (891.0 RPM)
# Calculating: Omega step 101/201 (900.0 RPM)
# Calculating: Omega step 102/201 (909.0 RPM)
# Calculating: Omega step 103/201 (918.0 RPM)
# Calculating: Omega step 104/201 (927.0 RPM)
# Calculating: Omega step 105/201 (936.0 RPM)
# Calculating: Omega step 106/201 (945.0 RPM)
# Calculating: Omega step 107/201 (954.0 RPM)
# Calculating: Omega step 108/201 (963.0 RPM)
# Calculating: Omega step 109/201 (972.0 RPM)
# Calculating: Omega step 110/201 (981.0 RPM)
# Calculating: Omega step 111/201 (990.0 RPM)
# Calculating: Omega step 112/201 (999.0 RPM)
# Calculating: Omega step 113/201 (1008.0 RPM)
# Calculating: Omega step 114/201 (1017.0 RPM)
# Calculating: Omega step 115/201 (1026.0 RPM)
# Calculating: Omega step 116/201 (1035.0 RPM)
# Calculating: Omega step 117/201 (1044.0 RPM)
# Calculating: Omega step 118/201 (1053.0 RPM)
# Calculating: Omega step 119/201 (1062.0 RPM)
# Calculating: Omega step 120/201 (1071.0 RPM)
# Calculating: Omega step 121/201 (1080.0 RPM)
# Calculating: Omega step 122/201 (1089.0 RPM)
# Calculating: Omega step 123/201 (1098.0 RPM)
# Calculating: Omega step 124/201 (1107.0 RPM)
# Calculating: Omega step 125/201 (1116.0 RPM)
# Calculating: Omega step 126/201 (1125.0 RPM)
# Calculating: Omega step 127/201 (1134.0 RPM)
# Calculating: Omega step 128/201 (1143.0 RPM)
# Calculating: Omega step 129/201 (1152.0 RPM)
# Calculating: Omega step 130/201 (1161.0 RPM)
# Calculating: Omega step 131/201 (1170.0 RPM)
# Calculating: Omega step 132/201 (1179.0 RPM)
# Calculating: Omega step 133/201 (1188.0 RPM)
# Calculating: Omega step 134/201 (1197.0 RPM)
# Calculating: Omega step 135/201 (1206.0 RPM)
# Calculating: Omega step 136/201 (1215.0 RPM)
# Calculating: Omega step 137/201 (1224.0 RPM)
# Calculating: Omega step 138/201 (1233.0 RPM)
# Calculating: Omega step 139/201 (1242.0 RPM)
# Calculating: Omega step 140/201 (1251.0 RPM)
# Calculating: Omega step 141/201 (1260.0 RPM)
# Calculating: Omega step 142/201 (1269.0 RPM)
# Calculating: Omega step 143/201 (1278.0 RPM)
# Calculating: Omega step 144/201 (1287.0 RPM)
# Calculating: Omega step 145/201 (1296.0 RPM)
# Calculating: Omega step 146/201 (1305.0 RPM)
# Calculating: Omega step 147/201 (1314.0 RPM)
# Calculating: Omega step 148/201 (1323.0 RPM)
# Calculating: Omega step 149/201 (1332.0 RPM)
# Calculating: Omega step 150/201 (1341.0 RPM)
# Calculating: Omega step 151/201 (1350.0 RPM)
# Calculating: Omega step 152/201 (1359.0 RPM)
# Calculating: Omega step 153/201 (1368.0 RPM)
# Calculating: Omega step 154/201 (1377.0 RPM)
# Calculating: Omega step 155/201 (1386.0 RPM)
# Calculating: Omega step 156/201 (1395.0 RPM)
# Calculating: Omega step 157/201 (1404.0 RPM)
# Calculating: Omega step 158/201 (1413.0 RPM)
# Calculating: Omega step 159/201 (1422.0 RPM)
# Calculating: Omega step 160/201 (1431.0 RPM)
# Calculating: Omega step 161/201 (1440.0 RPM)
# Calculating: Omega step 162/201 (1449.0 RPM)
# Calculating: Omega step 163/201 (1458.0 RPM)
# Calculating: Omega step 164/201 (1467.0 RPM)
# Calculating: Omega step 165/201 (1476.0 RPM)
# Calculating: Omega step 166/201 (1485.0 RPM)
# Calculating: Omega step 167/201 (1494.0 RPM)
# Calculating: Omega step 168/201 (1503.0 RPM)
# Calculating: Omega step 169/201 (1512.0 RPM)
# Calculating: Omega step 170/201 (1521.0 RPM)
# Calculating: Omega step 171/201 (1530.0 RPM)
# Calculating: Omega step 172/201 (1539.0 RPM)
# Calculating: Omega step 173/201 (1548.0 RPM)
# Calculating: Omega step 174/201 (1557.0 RPM)
# Calculating: Omega step 175/201 (1566.0 RPM)
# Calculating: Omega step 176/201 (1575.0 RPM)
# Calculating: Omega step 177/201 (1584.0 RPM)
# Calculating: Omega step 178/201 (1593.0 RPM)
# Calculating: Omega step 179/201 (1602.0 RPM)
# Calculating: Omega step 180/201 (1611.0 RPM)
# Calculating: Omega step 181/201 (1620.0 RPM)
# Calculating: Omega step 182/201 (1629.0 RPM)
# Calculating: Omega step 183/201 (1638.0 RPM)
# Calculating: Omega step 184/201 (1647.0 RPM)
# Calculating: Omega step 185/201 (1656.0 RPM)
# Calculating: Omega step 186/201 (1665.0 RPM)
# Calculating: Omega step 187/201 (1674.0 RPM)
# Calculating: Omega step 188/201 (1683.0 RPM)
# Calculating: Omega step 189/201 (1692.0 RPM)
# Calculating: Omega step 190/201 (1701.0 RPM)
# Calculating: Omega step 191/201 (1710.0 RPM)
# Calculating: Omega step 192/201 (1719.0 RPM)
# Calculating: Omega step 193/201 (1728.0 RPM)
# Calculating: Omega step 194/201 (1737.0 RPM)
# Calculating: Omega step 195/201 (1746.0 RPM)
# Calculating: Omega step 196/201 (1755.0 RPM)
# Calculating: Omega step 197/201 (1764.0 RPM)
# Calculating: Omega step 198/201 (1773.0 RPM)
# Calculating: Omega step 199/201 (1782.0 RPM)
# Calculating: Omega step 200/201 (1791.0 RPM)
# Calculating: Omega step 201/201 (1800.0 RPM)
# Recalculated Grid Calculation Complete.
# Recalculated grid successfully calculated and saved to 'c:\Users\matas\Desktop\CurrentSetpoints_main\data\IEEETIE_machine2_recalculated_0344.pkl'
# Plotting recalculated grid...

# %%
# 4. Compensated neural grid: full optimization with the neural model from
#    scratch (no warm starts from baseline).
neural_filename = os.path.join(data_dir, "IEEETIE_machine2_compensated_0344.pkl")

if os.path.isfile(neural_filename):
    print(f"Loading existing compensated neural grid from '{neural_filename}'...")
    with open(neural_filename, "rb") as file:
        neural_grid_result = pickle.load(file)
else:
    print(
        "Starting compensated neural grid calculation. "
        "This may take longer due to network inference..."
    )
    neural_grid_result = calculate_grid(
        optimizer=neural_optimizer, transform=transform, opts=grid_opts, mode="standard"
    )
    with open(neural_filename, "wb") as file:
        pickle.dump(neural_grid_result, file)
    print(
        f"Compensated neural grid successfully calculated and saved to '{neural_filename}'"
    )

print("Plotting compensated neural grid...")
neural_machine_data = grid_to_data(neural_grid_result, k_skip=1)
plot_grid_segments(neural_machine_data, title="4. Compensated Neural Grid")
# Out:
# Starting compensated neural grid calculation. This may take longer due to network inference...
# Starting Standard Grid Calculation...
# Calculating: Omega step 1/201 (0.0 RPM)
# Calculating: Omega step 2/201 (9.0 RPM)
# Calculating: Omega step 3/201 (18.0 RPM)
# Calculating: Omega step 4/201 (27.0 RPM)
# Calculating: Omega step 5/201 (36.0 RPM)
# Calculating: Omega step 6/201 (45.0 RPM)
# Calculating: Omega step 7/201 (54.0 RPM)
# Calculating: Omega step 8/201 (63.0 RPM)
# Calculating: Omega step 9/201 (72.0 RPM)
# Calculating: Omega step 10/201 (81.0 RPM)
# Calculating: Omega step 11/201 (90.0 RPM)
# Calculating: Omega step 12/201 (99.0 RPM)
# Calculating: Omega step 13/201 (108.0 RPM)
# Calculating: Omega step 14/201 (117.0 RPM)
# Calculating: Omega step 15/201 (126.0 RPM)
# Calculating: Omega step 16/201 (135.0 RPM)
# Calculating: Omega step 17/201 (144.0 RPM)
# Calculating: Omega step 18/201 (153.0 RPM)
# Calculating: Omega step 19/201 (162.0 RPM)
# Calculating: Omega step 20/201 (171.0 RPM)
# Calculating: Omega step 21/201 (180.0 RPM)
# Calculating: Omega step 22/201 (189.0 RPM)
# Calculating: Omega step 23/201 (198.0 RPM)
# Calculating: Omega step 24/201 (207.0 RPM)
# Calculating: Omega step 25/201 (216.0 RPM)
# Calculating: Omega step 26/201 (225.0 RPM)
# Calculating: Omega step 27/201 (234.0 RPM)
# Calculating: Omega step 28/201 (243.0 RPM)
# Calculating: Omega step 29/201 (252.0 RPM)
# Calculating: Omega step 30/201 (261.0 RPM)
# Calculating: Omega step 31/201 (270.0 RPM)
# Calculating: Omega step 32/201 (279.0 RPM)
# Calculating: Omega step 33/201 (288.0 RPM)
# Calculating: Omega step 34/201 (297.0 RPM)
# Calculating: Omega step 35/201 (306.0 RPM)
# Calculating: Omega step 36/201 (315.0 RPM)
# Calculating: Omega step 37/201 (324.0 RPM)
# Calculating: Omega step 38/201 (333.0 RPM)
# Calculating: Omega step 39/201 (342.0 RPM)
# Calculating: Omega step 40/201 (351.0 RPM)
# Calculating: Omega step 41/201 (360.0 RPM)
# Calculating: Omega step 42/201 (369.0 RPM)
# Calculating: Omega step 43/201 (378.0 RPM)
# Calculating: Omega step 44/201 (387.0 RPM)
# Calculating: Omega step 45/201 (396.0 RPM)
# Calculating: Omega step 46/201 (405.0 RPM)
# Calculating: Omega step 47/201 (414.0 RPM)
# Calculating: Omega step 48/201 (423.0 RPM)
# Calculating: Omega step 49/201 (432.0 RPM)
# Calculating: Omega step 50/201 (441.0 RPM)
# Calculating: Omega step 51/201 (450.0 RPM)
# Calculating: Omega step 52/201 (459.0 RPM)
# Calculating: Omega step 53/201 (468.0 RPM)
# Calculating: Omega step 54/201 (477.0 RPM)
# Calculating: Omega step 55/201 (486.0 RPM)
# Calculating: Omega step 56/201 (495.0 RPM)
# Calculating: Omega step 57/201 (504.0 RPM)
# Calculating: Omega step 58/201 (513.0 RPM)
# Calculating: Omega step 59/201 (522.0 RPM)
# Calculating: Omega step 60/201 (531.0 RPM)
# Calculating: Omega step 61/201 (540.0 RPM)
# Calculating: Omega step 62/201 (549.0 RPM)
# Calculating: Omega step 63/201 (558.0 RPM)
# Calculating: Omega step 64/201 (567.0 RPM)
# Calculating: Omega step 65/201 (576.0 RPM)
# Calculating: Omega step 66/201 (585.0 RPM)
# Calculating: Omega step 67/201 (594.0 RPM)
# Calculating: Omega step 68/201 (603.0 RPM)
# Calculating: Omega step 69/201 (612.0 RPM)
# Calculating: Omega step 70/201 (621.0 RPM)
# Calculating: Omega step 71/201 (630.0 RPM)
# Calculating: Omega step 72/201 (639.0 RPM)
# Calculating: Omega step 73/201 (648.0 RPM)
# Calculating: Omega step 74/201 (657.0 RPM)
# Calculating: Omega step 75/201 (666.0 RPM)
# Calculating: Omega step 76/201 (675.0 RPM)
# Calculating: Omega step 77/201 (684.0 RPM)
# Calculating: Omega step 78/201 (693.0 RPM)
# Calculating: Omega step 79/201 (702.0 RPM)
# Calculating: Omega step 80/201 (711.0 RPM)
# Calculating: Omega step 81/201 (720.0 RPM)
# Calculating: Omega step 82/201 (729.0 RPM)
# Calculating: Omega step 83/201 (738.0 RPM)
# Calculating: Omega step 84/201 (747.0 RPM)
# Calculating: Omega step 85/201 (756.0 RPM)
# Calculating: Omega step 86/201 (765.0 RPM)
# Calculating: Omega step 87/201 (774.0 RPM)
# Calculating: Omega step 88/201 (783.0 RPM)
# Calculating: Omega step 89/201 (792.0 RPM)
# Calculating: Omega step 90/201 (801.0 RPM)
# Calculating: Omega step 91/201 (810.0 RPM)
# Calculating: Omega step 92/201 (819.0 RPM)
# Calculating: Omega step 93/201 (828.0 RPM)
# Calculating: Omega step 94/201 (837.0 RPM)
# Calculating: Omega step 95/201 (846.0 RPM)
# Calculating: Omega step 96/201 (855.0 RPM)
# Calculating: Omega step 97/201 (864.0 RPM)
# Calculating: Omega step 98/201 (873.0 RPM)
# Calculating: Omega step 99/201 (882.0 RPM)
# Calculating: Omega step 100/201 (891.0 RPM)
# Calculating: Omega step 101/201 (900.0 RPM)
# Calculating: Omega step 102/201 (909.0 RPM)
# Calculating: Omega step 103/201 (918.0 RPM)
# Calculating: Omega step 104/201 (927.0 RPM)
# Calculating: Omega step 105/201 (936.0 RPM)
# Calculating: Omega step 106/201 (945.0 RPM)
# Calculating: Omega step 107/201 (954.0 RPM)
# Calculating: Omega step 108/201 (963.0 RPM)
# Calculating: Omega step 109/201 (972.0 RPM)
# Calculating: Omega step 110/201 (981.0 RPM)
# Calculating: Omega step 111/201 (990.0 RPM)
# Calculating: Omega step 112/201 (999.0 RPM)
# Calculating: Omega step 113/201 (1008.0 RPM)
# Calculating: Omega step 114/201 (1017.0 RPM)
# Calculating: Omega step 115/201 (1026.0 RPM)
# Calculating: Omega step 116/201 (1035.0 RPM)
# Calculating: Omega step 117/201 (1044.0 RPM)
# Calculating: Omega step 118/201 (1053.0 RPM)
# Calculating: Omega step 119/201 (1062.0 RPM)
# Calculating: Omega step 120/201 (1071.0 RPM)
# Calculating: Omega step 121/201 (1080.0 RPM)
# Calculating: Omega step 122/201 (1089.0 RPM)
# Calculating: Omega step 123/201 (1098.0 RPM)
# Calculating: Omega step 124/201 (1107.0 RPM)
# Calculating: Omega step 125/201 (1116.0 RPM)
# Calculating: Omega step 126/201 (1125.0 RPM)
# Calculating: Omega step 127/201 (1134.0 RPM)
# Calculating: Omega step 128/201 (1143.0 RPM)
# Calculating: Omega step 129/201 (1152.0 RPM)
# Calculating: Omega step 130/201 (1161.0 RPM)
# Calculating: Omega step 131/201 (1170.0 RPM)
# Calculating: Omega step 132/201 (1179.0 RPM)
# Calculating: Omega step 133/201 (1188.0 RPM)
# Calculating: Omega step 134/201 (1197.0 RPM)
# Calculating: Omega step 135/201 (1206.0 RPM)
# Calculating: Omega step 136/201 (1215.0 RPM)
# Calculating: Omega step 137/201 (1224.0 RPM)
# Calculating: Omega step 138/201 (1233.0 RPM)
# Calculating: Omega step 139/201 (1242.0 RPM)
# Calculating: Omega step 140/201 (1251.0 RPM)
# Calculating: Omega step 141/201 (1260.0 RPM)
# Calculating: Omega step 142/201 (1269.0 RPM)
# Calculating: Omega step 143/201 (1278.0 RPM)
# Calculating: Omega step 144/201 (1287.0 RPM)
# Calculating: Omega step 145/201 (1296.0 RPM)
# Calculating: Omega step 146/201 (1305.0 RPM)
# Calculating: Omega step 147/201 (1314.0 RPM)
# Calculating: Omega step 148/201 (1323.0 RPM)
# Calculating: Omega step 149/201 (1332.0 RPM)
# Calculating: Omega step 150/201 (1341.0 RPM)
# Calculating: Omega step 151/201 (1350.0 RPM)
# Calculating: Omega step 152/201 (1359.0 RPM)
# Calculating: Omega step 153/201 (1368.0 RPM)
# Calculating: Omega step 154/201 (1377.0 RPM)
# Calculating: Omega step 155/201 (1386.0 RPM)
# Calculating: Omega step 156/201 (1395.0 RPM)
# Calculating: Omega step 157/201 (1404.0 RPM)
# Calculating: Omega step 158/201 (1413.0 RPM)
# Calculating: Omega step 159/201 (1422.0 RPM)
# Calculating: Omega step 160/201 (1431.0 RPM)
# Calculating: Omega step 161/201 (1440.0 RPM)
# Calculating: Omega step 162/201 (1449.0 RPM)
# Calculating: Omega step 163/201 (1458.0 RPM)
# Calculating: Omega step 164/201 (1467.0 RPM)
# Calculating: Omega step 165/201 (1476.0 RPM)
# Calculating: Omega step 166/201 (1485.0 RPM)
# Calculating: Omega step 167/201 (1494.0 RPM)
# Calculating: Omega step 168/201 (1503.0 RPM)
# Calculating: Omega step 169/201 (1512.0 RPM)
# Calculating: Omega step 170/201 (1521.0 RPM)
# Calculating: Omega step 171/201 (1530.0 RPM)
# Calculating: Omega step 172/201 (1539.0 RPM)
# Calculating: Omega step 173/201 (1548.0 RPM)
# Calculating: Omega step 174/201 (1557.0 RPM)
# Calculating: Omega step 175/201 (1566.0 RPM)
# Calculating: Omega step 176/201 (1575.0 RPM)
# Calculating: Omega step 177/201 (1584.0 RPM)
# Calculating: Omega step 178/201 (1593.0 RPM)
# Calculating: Omega step 179/201 (1602.0 RPM)
# Calculating: Omega step 180/201 (1611.0 RPM)
# Calculating: Omega step 181/201 (1620.0 RPM)
# Calculating: Omega step 182/201 (1629.0 RPM)
# Calculating: Omega step 183/201 (1638.0 RPM)
# Calculating: Omega step 184/201 (1647.0 RPM)
# Calculating: Omega step 185/201 (1656.0 RPM)
# Calculating: Omega step 186/201 (1665.0 RPM)
# Calculating: Omega step 187/201 (1674.0 RPM)
# Calculating: Omega step 188/201 (1683.0 RPM)
# Calculating: Omega step 189/201 (1692.0 RPM)
# Calculating: Omega step 190/201 (1701.0 RPM)
# Calculating: Omega step 191/201 (1710.0 RPM)
# Calculating: Omega step 192/201 (1719.0 RPM)
# Calculating: Omega step 193/201 (1728.0 RPM)
# Calculating: Omega step 194/201 (1737.0 RPM)
# Calculating: Omega step 195/201 (1746.0 RPM)
# Calculating: Omega step 196/201 (1755.0 RPM)
# Calculating: Omega step 197/201 (1764.0 RPM)
# Calculating: Omega step 198/201 (1773.0 RPM)
# Calculating: Omega step 199/201 (1782.0 RPM)
# Calculating: Omega step 200/201 (1791.0 RPM)
# Calculating: Omega step 201/201 (1800.0 RPM)
# Standard Grid Calculation Complete.
# Compensated neural grid successfully calculated and saved to 'c:\Users\matas\Desktop\CurrentSetpoints_main\data\IEEETIE_machine2_compensated_0344.pkl'
# Plotting compensated neural grid...

# %%
# Global model performance: analytical vs. neural on experimental data.
# RMSE is computed on the held-out test split (matching the train/test
# partition used in model_trainer.ipynb), while the scatter plots show
# both train and test points for context. Train points are drawn hollow,
# test points filled.
import pandas as pd
from sklearn.model_selection import train_test_split

from current_setpoints.utils import load_aggregated_csv_data
from current_setpoints.utils.plotting import plot_global_performance

TEST_SIZE = 0.15
RANDOM_STATE = 42

CSV_PATH = os.path.join(data_dir, "aggregated_file_means.csv")
COL_MAP = {
    "omega": "omega",
    "id1": "id1",
    "iq1": "iq1",
    "id3": "id3",
    "iq3": "iq3",
    "torq": "torq_meas",
}

df_meas = load_aggregated_csv_data(CSV_PATH, COL_MAP)
df_meas = df_meas.reset_index(drop=True)
X_phys = df_meas[["omega", "id1", "iq1", "id3", "iq3"]].to_numpy(dtype=np.float32)

# Predict torque per row through both models. The analytical model's
# calculate_torque is fast; the neural wrapper's calculate_torque returns
# the analytical part PLUS the network residual (the new behavior of
# ModelNeural).
torq_ana_pred = np.zeros(len(X_phys), dtype=np.float64)
torq_neural_pred = np.zeros(len(X_phys), dtype=np.float64)
for i in range(len(X_phys)):
    omega_i = float(X_phys[i, 0])
    i_dq = X_phys[i, 1:].astype(np.float64)
    torq_ana_pred[i] = analytical_model.calculate_torque(omega_i, i_dq)
    torq_neural_pred[i] = neural_model_wrapper.calculate_torque(omega_i, i_dq)

df_meas["torq_Analytical"] = torq_ana_pred
df_meas["torq_Neural"] = torq_neural_pred
df_meas["Error_Analytical"] = df_meas["torq_Analytical"] - df_meas["torq_meas"]
df_meas["Error_Neural"] = df_meas["torq_Neural"] - df_meas["torq_meas"]

indices = np.arange(len(df_meas))
train_idx, test_idx = train_test_split(
    indices, test_size=TEST_SIZE, random_state=RANDOM_STATE
)
test_mask = np.zeros(len(df_meas), dtype=bool)
test_mask[test_idx] = True

rmse_ana_test = np.sqrt(np.mean(df_meas.loc[test_mask, "Error_Analytical"] ** 2))
rmse_nn_test = np.sqrt(np.mean(df_meas.loc[test_mask, "Error_Neural"] ** 2))
print(f"Analytical RMSE (test set, n={test_mask.sum()}): {rmse_ana_test:.4f} Nm")
print(f"Neural     RMSE (test set, n={test_mask.sum()}): {rmse_nn_test:.4f} Nm")

plot_global_performance(
    df_meas, machine, models=["Analytical", "Neural"], test_mask=test_mask
)
# Out:
# Loaded 174 valid data points from CSV.
# Analytical RMSE (test set, n=27): 0.1581 Nm
# Neural     RMSE (test set, n=27): 0.0344 Nm

# %%
# Torque residual heatmap: target torque - neural-predicted torque on baseline currents.
from current_setpoints.utils.plotting import plot_residual_torque_error

plot_residual_torque_error(correction_grid_result, machine)

# %%
# Joule loss reduction: baseline (analytical) vs. recalculated (neural-optimized) currents.
from current_setpoints.utils.plotting import plot_joule_losses_reduction

plot_joule_losses_reduction(correction_grid_result, recalc_grid_result, machine)
# Out:
# Analysis Complete. Max savings: 7.40 W

# %%
# Current trajectories: baseline (analytical) vs. compensated neural-optimized.
from current_setpoints.utils.plotting import plot_current_trajectories_split

plot_current_trajectories_split(grid_result, neural_grid_result, machine)
